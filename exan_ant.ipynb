# %%
# 어노테이션: 타입을 설명하는 표시 // 어떤 타입인지 미리 적어주는 표시
# 파이썬이 규칙을 검사하지 않기 때문에 입력이 자유로움

# 변수
age: int = 30 
print(age)


# 어노테이션은 강제 규칙이 아님 협업시 타입이 명확해지기 떄문에 관리가 쉬움

age : int = "안녕"
print(age)


#함수
def add(a:int, b:int) -> int:
    return a + b

#add(10, 20)
add("안녕", "반가워")


#리스트
nums : list[int] = [1,2,3]

#딕셔너리 dict[키값, Valuae값]
Person: dict[str, int] = {
    "age" : 30,
    "height" : 180
}

print(Person)
# Out:
# 30
# 안녕
# {'age': 30, 'height': 180}
